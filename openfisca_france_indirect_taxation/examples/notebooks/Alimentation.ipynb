# %% [markdown]
# # TVA sur les biens alimentaires

# %%
from __future__ import division

import os
import pandas as pd
import pkg_resources
import seaborn

from openfisca_france_indirect_taxation.surveys import SurveyScenario
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/__init__.py:874: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
year = 2014
data_year = 2011
survey_scenario = SurveyScenario.create(year = year, data_year = 2011, reform_key = 'aliss_tva_sociale')
# Out:
# ========================================================
# tva_sociale
#   code_bdf code_coicop       categorie_fiscale  start  stop  \
# 0   c01112  01.1.1.1.1  tva_taux_intermediaire   1994  2014
# 1   c01114  01.1.1.3.3  tva_taux_intermediaire   1994  2014
# 2   c01115  01.1.1.4.1  tva_taux_intermediaire   1994  2014
# 3   c01113  01.1.1.4.2  tva_taux_intermediaire   1994  2014
# 4   c01111  01.1.1.4.3  tva_taux_intermediaire   1994  2014
#
#                                                label
# 0  Pain et autres produits de boulangerie et de v...
# 1  Préparations telles que pâte à pâtisser, gâtea...
# 2  Autres céréales et produits à base de céréales...
# 3  Pâtes alimentaires sous toutes leurs formes et...
# 4  Riz sous toutes ses formes et produits à base ...
# --------

# %%
alimentation_domicile_hors_alcool = [
    "depenses_ht_{}".format(key) for key in survey_scenario.tax_benefit_system.column_by_name.keys() \
    if key.startswith(u'poste_01')
    ]
alimentation_hors_domicile = [
    key for key in survey_scenario.tax_benefit_system.column_by_name.keys() \
    if key.startswith('poste_11_1')
    ]
alimentation_domicile = alimentation_domicile_hors_alcool + [
    'depenses_biere',
    'depenses_vin',
    'depenses_alcools_forts'
    ] 

alimentation = alimentation_domicile + alimentation_hors_domicile

# %%
variables = alimentation + [
    'poste_agrege_01',
    'depenses_ht_tva_taux_intermediaire',
    'depenses_ht_tva_taux_reduit',
    'tva_taux_super_reduit',
    'tva_taux_reduit',
    'tva_taux_intermediaire',
    'tva_taux_plein',
    'tva_total',
    ]

# %%
pivot_table = pd.DataFrame()
aggregates = dict()
reference_aggregates = dict()
for variable in variables:
    pivot_table = pd.concat([
        pivot_table,
        survey_scenario.compute_pivot_table(values = [variable], columns = ['niveau_vie_decile'])
        ])
    aggregates[variable] = survey_scenario.compute_aggregate(variable) / 1e9
    reference_aggregates[variable] = survey_scenario.compute_aggregate(variable, reference = True) / 1e9

# %%
sum(aggregates[aliment] - reference_aggregates[aliment] for aliment in alimentation_domicile_hors_alcool)
# Out:
# 0.0

# %%
for key in aggregates.keys():
    if round(aggregates[key] - reference_aggregates[key], 3) != 0:
        print key, ': ', round(reference_aggregates[key], 3), '->', round(aggregates[key], 3), 'soit ', round(aggregates[key] - reference_aggregates[key], 2)
# Out:
# tva_taux_intermediaire :  7.559 -> 18.422 soit  10.86
# depenses_biere :  1.301 -> 0.0 soit  -1.3
# tva_taux_reduit :  7.069 -> 1.375 soit  -5.69
# tva_total :  77.924 -> 82.074 soit  4.15
# depenses_ht_tva_taux_intermediaire :  75.594 -> 184.217 soit  108.62
# tva_taux_plein :  63.155 -> 62.137 soit  -1.02
# depenses_ht_tva_taux_reduit :  128.528 -> 24.994 soit  -103.53
# poste_agrege_01 :  124.14 -> 128.399 soit  4.26

# %%
from openfisca_france_indirect_taxation.model.consommation.postes_coicop import get_legislation_data_frames
categories_fiscales_data_frame, codes_coicop_data_frame = get_legislation_data_frames()

# %%
aggregates['poste_agrege_01'] - reference_aggregates['poste_agrege_01']
# Out:
# 4.2585982890594494

# %%
reference_aggregates['poste_agrege_01'] * (.1 -.055) / ( 1 + .055)
# Out:
# 5.295074092848342

# %%
categories_fiscales_data_frame.query('"01.1" <= code_coicop <= "01.1.5"')
# Out:
#      code_coicop code_bdf categorie_fiscale  start  stop  \
# 0     01.1.1.1.1   c01112   tva_taux_reduit   1994  2014
# 5     01.1.1.3.3   c01114   tva_taux_reduit   1994  2014
# 6     01.1.1.4.1   c01115   tva_taux_reduit   1994  2014
# 7     01.1.1.4.2   c01113   tva_taux_reduit   1994  2014
# 8     01.1.1.4.3   c01111   tva_taux_reduit   1994  2014
# 10    01.1.2.1.1   c01121   tva_taux_reduit   1994  2014
# 15    01.1.2.3.1   c01123   tva_taux_reduit   1994  2014
# 17    01.1.2.4.1   c01122   tva_taux_reduit   1994  2014
# 18    01.1.2.4.2   c01125   tva_taux_reduit   1994  2014
# 23    01.1.2.5.1   c01124   tva_taux_reduit   1994  2014
# 26    01.1.2.6.1   c01127   tva_taux_reduit   1994  2014
# 28    01.1.2.6.3   c01126   tva_taux_reduit   1994  2014
# 29    01.1.3.1.1   c01130   tva_taux_reduit   1994  2014
# 30    01.1.3.1.2   c01132   tva_taux_reduit   1994  2014
# 31  01.1.3.2.1.a   c01131   tva_taux_reduit   1994  2014
# 32  01.1.3.2.1.b   c01133   tva_taux_reduit   1994  2014
# 33    01.1.3.2.2   c01134   tva_taux_reduit   1994  2014
# 34  01.1.4.1.1.a   c01141   tva_taux_reduit   1994  2014
# 35  01.1.4.1.1.b   c01142   tva_taux_reduit   1994  2014
# 36  01.1.4.1.1.c   c01143   tva_taux_reduit   1994  2014
# 38    01.1.4.2.1   c01144   tva_taux_reduit   1994  2014
# 39    01.1.4.2.2   c01146   tva_taux_reduit   1994  2014
# 40    01.1.4.3.1   c01145   tva_taux_reduit   1994  2014
# 45    01.1.4.4.1   c01147   tva_taux_reduit   1994  2014
#
#                                                 label
# 0   Pain et autres produits de boulangerie et de v...
# 5   Préparations telles que pâte à pâtisser, gâtea...
# 6   Autres céréales et produits à base de céréales...
# 7   Pâtes alimentaires sous toutes leurs formes et...
# 8   Riz sous toutes ses formes et produits à base ...
# 10                  Viande bovine fraîche ou surgelée
# 15        Viande ovine ou caprine fraîche ou surgelée
# 17                 Viande porcine fraîche ou surgelée
# 18  Viande séchée salée ou fumée, charcuterie et a...
# 23             Viande de volaille fraîche ou surgelée
# 26  Autres viandes comestibles fraîches ou surgelé...
# 28  Conserve de viande, produit de transformation ...
# 29                                     Poissons frais
# 30  Fruits de mer frais ou surgelés (yc cuits, nc ...
# 31  Poissons surgelés ou congelés (hors poissons p...
# 32  Poissons et fruits de mer salés, fumés, séchés...
# 33  Conserves de poisson et de fruits de mer et pl...
# 34                                        Lait entier
# 35                           Lait demi-écrémé, écrémé
# 36                                   Lait de conserve
# 38  Yaourts, fromage blanc et petits suisses yc de...
# 39  Autres produits laitiers (dessert à base de la...
# 40                             Fromage et lait caillé
# 45                                              Oeufs

# %%
categories_fiscales_data_frame.query('"01.1.5" <= code_coicop <= "01.5"')
# Out:
#      code_coicop code_bdf categorie_fiscale  start  stop  \
# 46    01.1.5.1.1   c01151   tva_taux_reduit   1994  2014
# 47  01.1.5.2.1.a   c01153   tva_taux_reduit   1994  2014
# 48  01.1.5.2.1.b   c01154   tva_taux_reduit   1994  2014
# 49  01.1.5.2.2.a   c01152    tva_taux_plein   1994  2014
# 50  01.1.5.2.2.b   c01155    tva_taux_plein   1994  2014
# 52  01.1.6.1.1.a   c01161   tva_taux_reduit   1994  2014
# 53  01.1.6.1.1.b   c01162   tva_taux_reduit   1994  2014
# 54  01.1.6.1.1.c   c01163   tva_taux_reduit   1994  2014
# 55  01.1.6.1.1.d   c01164   tva_taux_reduit   1994  2014
# 56  01.1.6.2.1.a   c01165   tva_taux_reduit   1994  2014
# 57  01.1.6.2.1.b   c01166   tva_taux_reduit   1994  2014
# 58  01.1.6.2.1.c   c01167   tva_taux_reduit   1994  2014
# 59  01.1.6.2.1.d   c01168   tva_taux_reduit   1994  2014
# 60  01.1.6.2.1.e   c01169   tva_taux_reduit   1994  2014
# 61  01.1.7.1.1.a   c01171   tva_taux_reduit   1994  2014
# 62  01.1.7.1.1.b   c01172   tva_taux_reduit   1994  2014
# 63  01.1.7.1.1.c   c01173   tva_taux_reduit   1994  2014
# 64  01.1.7.1.1.d   c01174   tva_taux_reduit   1994  2014
# 65  01.1.7.2.1.a   c01175   tva_taux_reduit   1994  2014
# 66  01.1.7.2.1.b   c01176   tva_taux_reduit   1994  2014
# 67  01.1.7.2.1.c   c01177   tva_taux_reduit   1994  2014
# 68    01.1.7.2.2   c01179   tva_taux_reduit   1994  2014
# 69    01.1.7.2.3   c01178   tva_taux_reduit   1994  2014
# 70  01.1.8.1.1.a   c01181   tva_taux_reduit   1994  2014
# 71  01.1.8.1.1.b   c01186   tva_taux_reduit   1994  2014
# 72  01.1.8.1.1.c   c01194   tva_taux_reduit   1994  2014
# 73    01.1.8.1.2   c01182   tva_taux_reduit   1994  2014
# 74    01.1.8.1.3   c01184    tva_taux_plein   1994  2014
# 75    01.1.8.2.1   c01183    tva_taux_plein   1994  2014
# 77    01.1.8.3.1   c01185   tva_taux_reduit   1994  2014
# 78  01.1.9.1.1.a   c01191   tva_taux_reduit   1994  2014
# 79  01.1.9.1.1.b   c01192   tva_taux_reduit   1994  2014
# 83    01.1.9.3.2   c01193   tva_taux_reduit   1994  2014
# 84      01.1.9.5   c01195   tva_taux_reduit   1994  2014
# 85       01.10.1   c01311   tva_taux_reduit   1994  2014
# 86       01.10.2   c01312   tva_taux_reduit   1994  2014
# 87    01.2.1.1.1   c01213   tva_taux_reduit   1994  2014
# 88    01.2.1.2.1   c01211   tva_taux_reduit   1994  2014
# 90    01.2.1.3.1   c01212   tva_taux_reduit   1994  2014
# 91    01.2.2.1.1   c01221   tva_taux_reduit   1994  2014
# 92    01.2.2.2.1   c01224   tva_taux_reduit   1994  2014
# 93    01.2.2.2.2   c01222   tva_taux_reduit   1994  2014
# 94    01.2.2.2.3   c01223   tva_taux_reduit   1994  2014
#
#                                                 label
# 46                                             Beurre
# 47                        Huiles alimentaires d'olive
# 48  Huiles alimentaires d'arachide, de tournesol, ...
# 49    Margarine, allégés et autres graisses végétales
# 50      saindoux et autres graisses d'origine animale
# 52                        agrumes (frais ou congelés)
# 53                                   bananes fraiches
# 54                                             pommes
# 55                                             poires
# 56                fruits à noyaux (frais ou congelés)
# 57                      baies (fraîches ou congelées)
# 58  autres fruits, fruits tropicaux (frais ou cong...
# 59                                      fruits séchés
# 60                 fruits au sirop et fruits surgelés
# 61  légumes frais à feuilles et à tiges, herbes ar...
# 62                                      choux (frais)
# 63           légumes frais cultivés pour leurs fruits
# 64  racines alimentaires fraiches et champignons f...
# 65                                       légumes secs
# 66                    légumes surgelés (non cuisinés)
# 67  légumes et plats à base de légume, en conserve...
# 68  pomme de terre, autres tubercules, produits à ...
# 69  légumes préparés et plats à base de légumes, f...
# 70                                              sucre
# 71                    autres produits à base de sucre
# 72                       autres produits alimentaires
# 73  confitures, marmelade, compote, gelées, purées...
# 74           sucreries, bonbons et autres confiseries
# 75                                           chocolat
# 77          crèmes glacées, sorbets, entremets glacés
# 78                               sauces et condiments
# 79                               sel et épices sèches
# 83        levure , préparations pour desserts, soupes
# 84                                 Panier alimentaire
# 85  autres dépenses d'alimentation : cérémonies, s...
# 86  autres dépenses d'alimentation : cadeau offert...
# 87                        cacao et chocolat en poudre
# 88                                               café
# 90                          thé et plantes à infusion
# 91                                     eaux minérales
# 92                                     jus de légumes
# 93                                  boissons gazeuses
# 94  jus de fruits et de légumes, sirops, boissons ...

# %%
categories_fiscales_data_frame.query('start == 0')
# Out:
# Empty DataFrame
# Columns: [code_coicop, code_bdf, categorie_fiscale, start, stop, label]
# Index: []

# %%
survey_scenario.compute_aggregate('poste_01_1_5_2_2_a') / 1e9
# Out:
# 0.47433468400000001

# %%
survey_scenario.compute_aggregate('poste_01_1_5_2_2_b') / 1e9
# Out:
# 0.012584329

# %%
categories_fiscales_data_frame.query('categorie_fiscale == "tva_taux_intermediaire"')
# Out:
#     code_coicop code_bdf       categorie_fiscale  start  stop  \
# 160  04.4.1.1.1   c04431  tva_taux_intermediaire   2012  2014
# 161  04.4.1.2.1   c04411  tva_taux_intermediaire   2012  2014
# 163  04.4.1.3.1   c04421  tva_taux_intermediaire   2012  2014
# 261  07.3.1.1.1   c07311  tva_taux_intermediaire   2012  2014
# 263  07.3.2.1.1   c07321  tva_taux_intermediaire   2012  2014
# 268  07.3.3.1.1   c07331  tva_taux_intermediaire   2012  2014
# 271  07.3.5.1.1   c07351  tva_taux_intermediaire   2012  2014
# 273  07.3.6.1.1   c07361  tva_taux_intermediaire   2012  2014
# 275  07.3.6.1.2   c07341  tva_taux_intermediaire   2012  2014
# 310  09.4.1.1.2   c09411  tva_taux_intermediaire   2012  2014
# 314  09.4.2.1.1   c09421  tva_taux_intermediaire   2012  2014
# 319  09.4.2.2.2   c09422  tva_taux_intermediaire   2012  2014
# 320  09.4.2.3.1   c09423  tva_taux_intermediaire   2012  2014
# 322  09.4.2.4.1   c09424  tva_taux_intermediaire   2012  2014
# 329  09.5.1.1.2   c09511  tva_taux_intermediaire   2012  2014
# 351  11.1.1.1.1   c11111  tva_taux_intermediaire   2012  2014
# 354  11.1.1.1.2   c11112  tva_taux_intermediaire   2012  2014
# 367  11.2.1.1.1   c11211  tva_taux_intermediaire   2012  2014
# 395  12.4.1.1.1   c12411  tva_taux_intermediaire   2012  2014
#
#                                                  label
# 160  Factures d’eau résidence principale, autre log...
# 161                 Redevance d’enlèvement des ordures
# 163                          Services d’assainissement
# 261  Services de transports de voyageurs locaux (mé...
# 263  Services de transports de voyageurs par route ...
# 268  Services de transports de voyageurs par air (y...
# 271  Services combinés de transport de voyageurs ca...
# 273     Autres services de transport (yc déménagement)
# 275  Services de transport par mer et voies navigab...
# 310  Services sportifs et récréatifs (spectacles sp...
# 314  Cinémas, théâtres, salles de concert, cirques,...
# 319          Musées, jardins zoologiques et similaires
# 320  Services de télévision et de radiodiffusion (l...
# 322  Smartbox et autres services de loisirs (animat...
# 329                                  Livres yc e-books
# 351                      Repas pris dans un restaurant
# 354           Repas pris dans un café, bar ou assimilé
# 367  Services d’hébergement (hôtels, gîtes, camping...
# 395  Services de protection sociale (assistante mat...
